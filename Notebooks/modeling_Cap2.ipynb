# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# Load the data
df = pd.read_csv('joined_data_train.csv')

# %%
df.head()
# Out:
#    respondent_id        h1n1_concern      h1n1_knowledge  \
# 0              0  Not very concerned        No knowledge
# 1              1      Very concerned  A lot of knowledge
# 2              2  Not very concerned  A little knowledge
# 3              3  Not very concerned  A little knowledge
# 4              4  Somewhat concerned  A little knowledge
#
#       behavioral_antiviral_meds behavioral_avoidance behavioral_face_mask  \
# 0  Not on antiviral medications        Did not avoid    Did not wear mask
# 1  Not on antiviral medications              Avoided    Did not wear mask
# 2  Not on antiviral medications              Avoided    Did not wear mask
# 3  Not on antiviral medications              Avoided    Did not wear mask
# 4  Not on antiviral medications              Avoided    Did not wear mask
#
#   behavioral_wash_hands     behavioral_large_gatherings  \
# 0    Did not wash hands  Did not avoid large gatherings
# 1          Washed hands  Did not avoid large gatherings
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df['household_children'].unique()
# Out:
# array(['0.0', '3.0', '2.0', '1.0', 'Unknown'], dtype=object)

# %%
household_children = pd.get_dummies(df['household_children'],drop_first=True)

# %%
household_children.head()
# Out:
#      1.0    2.0    3.0  Unknown
# 0  False  False  False    False
# 1  False  False  False    False
# 2  False  False  False    False
# 3  False  False  False    False
# 4  False  False  False    False

# %%
new_df = pd.get_dummies(df, drop_first=True)

# %%
# Apply pd.get_dummies using lambda function to every column in the dataframe
#new_df = df.apply(lambda x: pd.get_dummies(x, drop_first=True), axis=0)

# %%
new_df.head()
# Out:
#    respondent_id  h1n1_concern_Not very concerned  \
# 0              0                             True
# 1              1                            False
# 2              2                             True
# 3              3                             True
# 4              4                            False
#
#    h1n1_concern_Somewhat concerned  h1n1_concern_Unknown  \
# 0                            False                 False
# 1                            False                 False
# 2                            False                 False
# 3                            False                 False
# 4                             True                 False
#
#    h1n1_concern_Very concerned  h1n1_knowledge_A lot of knowledge  \
# 0                        False                              False
# 1                         True                               True
# 2                        False                              False
# ...
